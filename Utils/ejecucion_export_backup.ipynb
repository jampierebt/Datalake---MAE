# %%
from google.cloud import bigquery
from google.cloud import storage
import concurrent.futures
import re
import os
import pandas as pd

project_id = 'iter-data-storage-pv-uat'
dataset_id = 'acsele_data'
bucket_name='interseguro-datalake-alloy-uat-new'
path_insert='Desarrollo/Replicacion_insert/'
dataset_output='acsele_temp'
dataset_input='acsele_data'
path_ddl='Desarrollo/Replicacion_ddl/'
path_truncate='Desarrollo/Replicacion_truncate/'

# %%
sql =f"""
SELECT 
TABLE_CATALOG
,TABLE_SCHEMA
,TABLE_NAME
,REPLACE(REPLACE(REPLACE(REPLACE(DDL,'{dataset_id}','acsele_temp'),');',CONCAT(')OPTIONS (format="PARQUET",URIS=["gs://{bucket_name}/{dataset_id}/',TABLE_NAME,'/*.parquet"]);')),'CREATE TABLE','CREATE OR REPLACE EXTERNAL TABLE'),'PARTITION BY DATE(AUDITDATE)','') AS DDL
FROM {project_id}.{dataset_id}.INFORMATION_SCHEMA.TABLES
"""

# %%
def generate_blobs(dataset,table_name):
    client_storage = storage.Client(project=project_id)
    bucket = client_storage.bucket(bucket_name)
    blobs = bucket.list_blobs(prefix=f'{dataset}/{table_name}')
    return blobs

# %%
def delete_blob(blob):
    blob.delete()
    print(f'Archivo {blob.name} eliminado.')

# %%
def clean_storage(dataset_id,project_id):
    client = bigquery.Client(project_id)
    tables = client.list_tables(dataset_id)
    for table in tables:
        table_id = table.table_id
        blobs = generate_blobs(dataset_id,table_id)
        with concurrent.futures.ThreadPoolExecutor() as executor:
            futures = [executor.submit(delete_blob, blob) for blob in blobs]
            concurrent.futures.wait(futures)  
    return f"Limpieza ruta: {dataset_id}/{table_id}"

# %%
def export_table_storage(dataset_id,project_id):
    client = bigquery.Client(project_id)
    dataset_ref = client.dataset(dataset_id)
    tables = client.list_tables(dataset_ref)
    for table in tables:
        table_id = table.table_id
        table_ref = dataset_ref.table(table_id)
        uri = f'gs://{bucket_name}/{dataset_id}/{table_id}/*.parquet'
        extract_job = client.extract_table(
            table_ref,
            uri,
            location="US",
            job_config=bigquery.ExtractJobConfig(destination_format="PARQUET")
            )
        print(f'Tabla Exportada: {table_ref}')

# %%
def read_table_bq(query):
  df = pd.read_gbq(query, project_id=project_id, dialect='standard')
  return df

# %%
def sqlbigquery(file):
    with open(file,"r") as file:
        statement = file.readlines()
        statement = " ".join(statement)
    return statement

# %%
def execute_job(query,project_id):
    client = bigquery.Client(project_id)
    query_job = client.query(query)
    results = query_job.result()
    for row in results:
        print(row)
        table_name = row['TABLE_NAME']
        ddl_statement = row['DDL']
        client.query(ddl_statement).result()
        print(f'Tabla creada: {table_name}')
    return f'Ejectuado Correctamente'

# %%
def store_base(path,df):
  for index, row in df.iterrows():
    nombre_archivo = row['TABLE_NAME']
    contenido_archivo = row['DDL']
    with open(path + nombre_archivo+'.sql', 'w', newline='') as archivo:
      archivo.write(contenido_archivo)
  return 'Se exporto correctamente los DDL'

# %%
def external_to_table(path,dataset_id,dataset_output,dataset_input):
    client = bigquery.Client(project_id)
    dataset_ref = client.dataset(dataset_id)
    tables = client.list_tables(dataset_ref)
    for table in tables:
        table_id = table.table_id
        table_ref = dataset_ref.table(table_id)
        with open(path+table_id+'.sql','w') as file:
            file.write('INSERT INTO '+project_id+'.'+dataset_input+'.'+table_id+'\n')
            file.write('SELECT * FROM '+project_id+'.'+dataset_output+'.'+table_id)

# %%
def execute_job_bq(path,type):
    client = bigquery.Client(project_id)
    list_sql = os.listdir(path)
    for file in list_sql:
        print(f" Query {type} a BQ: {file}")
        query = sqlbigquery(path+file)
        query_job = client.query(query)
        query_job.result()

# %%
def generate_truncate(path,dataset_id):
    client = bigquery.Client(project_id)
    dataset_ref = client.dataset(dataset_id)
    tables = client.list_tables(dataset_ref)
    for table in tables:
        table_id = table.table_id
        table_ref = dataset_ref.table(table_id)
        with open(path+table_id+'.sql','w') as file:
            file.write('TRUNCATE TABLE '+project_id+'.'+dataset_id+'.'+table_id)

# %%
generate_truncate(path_truncate,dataset_input)

# %% [markdown]
# ### Main que realiza el exportado a cloud storage

# %%
def main_export_storage():
    #clean_storage(dataset_id,project_id)
    export_table_storage(dataset_id,project_id)
    return "Ejecutado Correctamente"

# %%
main_export_storage()
# Out:
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.ACCIDENTADO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.ACCIDENTADO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.AGREGATEDINSURANCEOBJECT_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.AGREGATEDPOLICYTYPE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.AGREGATEDPOLICYTYPE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.AGREGATEDPOLICY_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.AGREGINSOBJECTTYPE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.AGREGINSOBJECTTYPE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.ATROPELLOSIN_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CDTR_TRANSFORMERTRANSLATION_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CLAIMINSURANCEOBJECT_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CLAIMNORMALRESERVE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CLAIMPAYMENT_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CLAIMRESERVEADJUST_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CLAIMRISKUNIT_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CLAIM_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.COBERTURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CONFIGURABLEOBJECTTYPE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CONFIGURABLEOBJECTTYPE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CONFIGURATEDCOVERAGE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CONFIGURATEDCOVERAGE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CONTEXTOPERATION_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CONTRATANTEPOL_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CONTRATANTEPOL_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.COTPROPERTY_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.COTPROPERTY_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.COVERAGEDCO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.COVERAGETITLE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CURRENCYRATE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CURRENCYRATE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CURRENCY_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.CURRENCY_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.DIRECCION
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.DIRECCION_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EVENTDCO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EVENTTYPE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EVENTTYPE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_ASEGURADO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_CARGOS_ACUM_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_CARGOS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_COBERTURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_CONTRATANTE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_FONDOS_FIN_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_FONDOS_INI_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_POLIZA_PAGOS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_POLIZA_UNI_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_PRIMA_MONTO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_RPT_COBERTURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_RPT_FLEXDETALLE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_RPT_FLEXRESUMEN_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_RPT_POLIZAFLEXRANGO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_FLEX_RPT_PORTAFOLIO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_POLIZA_TIR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_PORTAFOLIO_CAB_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_PORTAFOLIO_DET_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_RENTABILIDAD_CAB_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_RENTABILIDAD_DET_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.EXT_RISKRESERVEJOB_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.INSURANCEOBJECTDCO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.LUGAR_SINIESTRO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.MIR_REP_VALORES_GARANTIZADOS_VIDA_202310_RAW
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAACCIDENTEASISTEN_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAACCIDENTEASISTEN_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OACLONACIONOFRAUDED_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OACLONACIONOFRAUDED_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGHIPOTECARIOIND_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGHIPOTECARIOIND_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGHIPOTECARIO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGHIPOTECARIO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGPERSONALIND_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGPERSONALIND_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGPERSONAL_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGPERSONAL_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGTARJETASIND_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGTARJETASIND_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGTARJETAS_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGTARJETAS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGVEHICULARIND_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGVEHICULARIND_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGVEHICULAR_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADESGVEHICULAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADOTALDOBLECAPITAL_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADOTALDOBLECREC_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADOTALDOBLEPROTEC_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADOTALSIMPLESURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADOTALSIMPLE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADOTALTRIPLECREC_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OADOTALTRIPLEPROTEC_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAEDUCACIONALSURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAEDUCGARANTIZADAPLUSNEW_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAEDUCGARANTIZADAPLUS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAEDUCGARANTIZADA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAEXTRACASHFUNO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAEXTRACASHFUNO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAEXTRACASH_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAEXTRACASH_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAFLEX65_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAFLEX65_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAFLEX80_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAFLEX80_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAGARANTIAEXTENDIDA_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAGARANTIAEXTENDIDA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAINTELIGO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAINTELIGO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAINTERBANKACCIDENTES_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAINTERBANKACCIDENTES_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAINTERKIDS_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAINTERKIDS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAMUERTEACCVIAJES_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAMUERTEACCVIAJES_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPLANGARANTIZADO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTBLINDAJEINDPLUS_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTBLINDAJEINDPLUS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTBLININDPLUSFUNO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTBLININDPLUSFUNO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCFINANCOH_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCFINANCOH_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCIONBLINDAJEPLUS_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCIONBLINDAJEPLUS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCIONBLINDAJE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCIONBLINDAJE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCIONCREDITOSSCC_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCIONCREDITOSSCC_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCIONCREDITOS_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCIONCREDITOS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCIONCREDITO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCIONCREDITO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCIONDEBITO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCIONDEBITO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCIONFAMILIAR_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPROTECCIONFAMILIAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPTINDIVIDUALIBK_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPTINDIVIDUALOH_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAPTINDIVIDUALOH_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAREFINANCIADOCONV_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAREFINANCIADOCONV_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OASCTR_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OASCTR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OASEGUNDOASEGURADOSURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OASEGUROACCIDENTES_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OASEGUROTEMPDEVPRIMAS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OASEGVEHICULARMODULAR_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OASEGVEHICULARMODULAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OASIEMPRESEGURO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OASOAT_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OASOAT_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OATARJETADECREDITO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OATARJETADECREDITO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OATARJETADEDEBITO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OATARJETADEDEBITO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OATEMPGARANTIZADO100_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OATEMPGARANTIZADO75_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OATEMPORALSURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVEAACCIDENTES_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVEAACCIDENTES_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVEAVIDA_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVEAVIDA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVEHICULAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDAENTERABENEFANT_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDAENTERASURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDAENTERA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDAESTUDIOSPLUS_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDAESTUDIOSPLUS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDAESTUDIOS_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDAESTUDIOS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDAFREE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDAFREE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDAGRUPOCOMP_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDAGRUPOCOMP_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDAINVERSION_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDAINVERSION_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDALEYTTL_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDALEYTTL_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDAPROTEGIDA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDATEMPORAL_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OAVIDATOTALPROTEGIDA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OPENITEMREFERENCE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OPENITEMREFERENCE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.OPENITEM_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PAGADO_HASTA_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PAGADO_HASTA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PAYMENTORDER_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PERSONAJURIDICA_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PERSONAJURIDICA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PERSONANATURAL_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PERSONANATURAL_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PLAN_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PLAN_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLACCIDENTEASISTEN_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLACCIDENTEASISTEN_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLCLONACIONOFRAUDED_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLCLONACIONOFRAUDED_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGHIPOTECARIOIND_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGHIPOTECARIOIND_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGHIPOTECARIO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGHIPOTECARIO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGPERSONALIND_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGPERSONALIND_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGPERSONAL_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGPERSONAL_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGRAVAMENIND_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGRAVAMENIND_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGTARJETASIND_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGTARJETASIND_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGTARJETAS_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGTARJETAS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGVEHICULARIND_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGVEHICULARIND_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGVEHICULAR_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDESGVEHICULAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDOTALDOBLECAPITAL_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDOTALDOBLECREC_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDOTALDOBLEPROTEC_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDOTALSIMPLESURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDOTALSIMPLE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDOTALTRIPLECREC_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLDOTALTRIPLEPROTEC_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLEDUCACIONALSURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLEDUCGARANTIZADAPLUSNEW_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLEDUCGARANTIZADAPLUS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLEDUCGARANTIZADA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLEXTRACASHFUNO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLEXTRACASHFUNO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLEXTRACASH_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLEXTRACASH_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLFLEX65_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLFLEX65_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLFLEX80_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLFLEX80_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLGARANTIAEXTENDIDA_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLGARANTIAEXTENDIDA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLICYDCO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLINTELIGO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLINTELIGO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLINTERBANKACCIDENTES_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLINTERBANKACCIDENTES_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLINTERKIDS_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLINTERKIDS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLIZA_OPERACION_EVENT_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLMUERTEACCVIAJES_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLMUERTEACCVIAJES_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPLANGARANTIZADO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTBLINDAJEINDPLUSFU_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTBLINDAJEINDPLUSFU_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTBLINDAJEINDPLUS_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTBLINDAJEINDPLUS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTECCFINANCOH_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTECCFINANCOH_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTECCIONBLINDAJEPLUS_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTECCIONBLINDAJEPLUS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTECCIONBLINDAJE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTECCIONBLINDAJE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTECCIONCREDITOSSCC_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTECCIONCREDITOSSCC_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTECCIONCREDITOS_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTECCIONCREDITOS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTECCIONDEBITO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTECCIONDEBITO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTECCIONFAMILIAR_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPROTECCIONFAMILIAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPTINDIVIDUALIBK_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPTINDIVIDUALIBK_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPTINDIVIDUALOH_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLPTINDIVIDUALOH_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLREFINANCIADOCONV_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLREFINANCIADOCONV_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLREFINANCIADOIND_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLREFINANCIADOIND_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLSCTR_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLSCTR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLSEGUNDOASEGURADOSURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLSEGUROACCIDENTES_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLSEGVEHICULARMODULAR_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLSEGVEHICULARMODULAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLSIEMPRESEGURO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLSOAT_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLTARJETADECREDITO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLTARJETADECREDITO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLTARJETADEDEBITO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLTEMDEVPRIMA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLTEMPGARANTIZADO100_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLTEMPGARANTIZADO75_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLTEMPORALSURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVEAACCIDENTES_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVEAACCIDENTES_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVEAVIDA_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVEAVIDA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVEHICULAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDAENTERABENEFANT_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDAENTERASURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDAENTERA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDAESTUDIOSPD_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDAESTUDIOSPD_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDAESTUDIOS_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDAESTUDIOS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDAFREE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDAFREE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDAGRUPOCOMP_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDAGRUPOCOMP_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDAINVERSION_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDAINVERSION_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDALEYTTL_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDALEYTTL_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDAPROTEGIDA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDATEMPORAL_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.POLVIDATOTALPROTEGIDA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PREINSUREDOBJECT_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PREPOLICY_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PREPRODUCT_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PREPRODUCT_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PRETHIRDPARTY_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PRIMA_OPERACION_COBERTURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PRODUCT_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PRODUCT_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PROPERTY_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PROPERTY_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PolVidaCashStock_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PolVidaCashStock_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.PolVidaCash_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.REFUND_PORCENTAGE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.RISKUNITDCO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STATE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STATE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STCA_DOCTYPE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STCA_DOCTYPE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STCL_COVERAGEINVOICE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STCL_COVERAGEINVOICE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STLI_FUNDMOVEMENTPOLICY_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STPO_INSOBJPARTICIPATIONDCO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STPO_INSOBJPARTICIPATION_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STPO_POLICYPARTICIPATIONDCO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STPO_POLICYPARTICIPATIONDCO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STPO_POLICYPARTICIPATION_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STPO_WILDCARDQUOTA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STTE_THIRDPARTYADDRESSBOOK_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STTE_THIRDPARTY_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STTS_ROLE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.STTS_ROLE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.Siniestro_ti_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TBL_UBIGEO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TBL_UBIGEO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TCM007_202312_RAW
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TCM007_EXTRACASH_FUNO062023_RAW
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TCM007_OTROS102023_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TCM007_SOAT102023_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TDTASACAMBSBS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_ESTADO_ANULAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_ESTADO_CADUCAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_ESTADO_CANCELAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_ESTADO_ENDOSO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_ESTADO_ENDOSO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_ESTADO_RECHAZAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_ESTADO_REHABILITAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_ESTADO_RENOVAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_ESTADO_RESCATAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_ESTADO_TERMINAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_OPENITEM
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_OPENITEM_COMPROBANTE
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_OPENITEM_MAESTRA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_OPERACION_BENEFICIARIO_POL_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_OPERACION_BENEFICIARIO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_OPERACION_MASIVOS_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_OPERACION_SOAT_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_OPERACION_UNIDAD_RIESGO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_OPERACION_VEHICULAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_OPERACION_VIDA_AGENTE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_ASEGURADO_BETTERFLY_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_ASEGURADO_DESGTARJETASIND_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_ASEGURADO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_COMODIN_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_CONTRATANTE_GE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_CONTRATANTE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_CONTRATANTE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_ENDOSO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_OPERACION_COBERTURA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_OPERACION_UNIDAD_RIESGO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_SINIESTRO_PAGO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_SINIESTRO_RESERVA_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_SINIESTRO_RESERVA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_SINIESTRO_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_SINIESTRO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_POLIZA_TVG_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_PRODUCTO_CENTRO_COSTO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.TD_PRODUCTO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.THIRDPARTYMOVEMENTPOLICY_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.THIRDPARTYMOVEMENTPOLICY_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.URPVIDAFREE_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.URSEGVEHICULARMODULAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.URVEHICULAR_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.URVEHICULAR_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.URVIDAFREE_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.URVIDATOTALPROTEGIDA_landing
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.URVIDATOTALPROTEGIDA_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.VIEW_PRESTAMO_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.VIEW_PROPIEDAD_VALORES_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.VIEW_PROPLISTA_DEPEN_raw
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.claiminsuranceobject
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.claimnormalreserve
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.claimriskunit
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.personajuridica
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.personanatural
# Tabla Exportada: iter-data-storage-pv-uat.acsele_data.stcl_paymentliquidation
# 'Ejecutado Correctamente'

# %% [markdown]
# ### Main que crea los ddl para las tablas externas en bq

# %%
def main_create_external_table():
    store_base(path_ddl,read_table_bq(sql))
    #execute_job(sql,project_id)
    return "Ejecutado Correctamente"

# %%
main_create_external_table()

# %%
execute_job_bq(path_ddl,'DDL')
# Out:
#  Query DDL a BQ: ACCIDENTADO_landing.sql
#  Query DDL a BQ: ACCIDENTADO_raw.sql
#  Query DDL a BQ: AGREGATEDINSURANCEOBJECT_raw.sql
#  Query DDL a BQ: AGREGATEDPOLICYTYPE_landing.sql
#  Query DDL a BQ: AGREGATEDPOLICYTYPE_raw.sql
#  Query DDL a BQ: AGREGATEDPOLICY_raw.sql
#  Query DDL a BQ: AGREGINSOBJECTTYPE_landing.sql
#  Query DDL a BQ: AGREGINSOBJECTTYPE_raw.sql
#  Query DDL a BQ: ATROPELLOSIN_raw.sql
#  Query DDL a BQ: CDTR_TRANSFORMERTRANSLATION_raw.sql
#  Query DDL a BQ: claiminsuranceobject.sql
#  Query DDL a BQ: CLAIMINSURANCEOBJECT_raw.sql
#  Query DDL a BQ: claimnormalreserve.sql
#  Query DDL a BQ: CLAIMNORMALRESERVE_raw.sql
#  Query DDL a BQ: CLAIMPAYMENT_raw.sql
#  Query DDL a BQ: CLAIMRESERVEADJUST_raw.sql
#  Query DDL a BQ: claimriskunit.sql
#  Query DDL a BQ: CLAIMRISKUNIT_raw.sql
#  Query DDL a BQ: CLAIM_raw.sql
#  Query DDL a BQ: COBERTURA_raw.sql
#  Query DDL a BQ: CONFIGURABLEOBJECTTYPE_landing.sql
#  Query DDL a BQ: CONFIGURABLEOBJECTTYPE_raw.sql
#  Query DDL a BQ: CONFIGURATEDCOVERAGE_landing.sql
#  Query DDL a BQ: CONFIGURATEDCOVERAGE_raw.sql
#  Query DDL a BQ: CONTEXTOPERATION_raw.sql
#  Query DDL a BQ: CONTRATANTEPOL_landing.sql
#  Query DDL a BQ: CONTRATANTEPOL_raw.sql
#  Query DDL a BQ: COTPROPERTY_landing.sql
#  Query DDL a BQ: COTPROPERTY_raw.sql
#  Query DDL a BQ: COVERAGEDCO_raw.sql
#  Query DDL a BQ: COVERAGETITLE_raw.sql
#  Query DDL a BQ: CURRENCYRATE_landing.sql
#  Query DDL a BQ: CURRENCYRATE_raw.sql
#  Query DDL a BQ: CURRENCY_landing.sql
#  Query DDL a BQ: CURRENCY_raw.sql
#  Query DDL a BQ: DIRECCION.sql
#  Query DDL a BQ: DIRECCION_raw.sql
#  Query DDL a BQ: EVENTDCO_raw.sql
#  Query DDL a BQ: EVENTTYPE_landing.sql
#  Query DDL a BQ: EVENTTYPE_raw.sql
#  Query DDL a BQ: EXT_FLEX_ASEGURADO_raw.sql
#  Query DDL a BQ: EXT_FLEX_CARGOS_ACUM_raw.sql
#  Query DDL a BQ: EXT_FLEX_CARGOS_raw.sql
#  Query DDL a BQ: EXT_FLEX_COBERTURA_raw.sql
#  Query DDL a BQ: EXT_FLEX_CONTRATANTE_raw.sql
#  Query DDL a BQ: EXT_FLEX_FONDOS_FIN_raw.sql
#  Query DDL a BQ: EXT_FLEX_FONDOS_INI_raw.sql
#  Query DDL a BQ: EXT_FLEX_POLIZA_PAGOS_raw.sql
#  Query DDL a BQ: EXT_FLEX_POLIZA_UNI_raw.sql
#  Query DDL a BQ: EXT_FLEX_PRIMA_MONTO_raw.sql
#  Query DDL a BQ: EXT_FLEX_RPT_COBERTURA_raw.sql
#  Query DDL a BQ: EXT_FLEX_RPT_FLEXDETALLE_raw.sql
#  Query DDL a BQ: EXT_FLEX_RPT_FLEXRESUMEN_raw.sql
#  Query DDL a BQ: EXT_FLEX_RPT_POLIZAFLEXRANGO_raw.sql
#  Query DDL a BQ: EXT_FLEX_RPT_PORTAFOLIO_raw.sql
#  Query DDL a BQ: EXT_POLIZA_TIR_raw.sql
#  Query DDL a BQ: EXT_PORTAFOLIO_CAB_raw.sql
#  Query DDL a BQ: EXT_PORTAFOLIO_DET_raw.sql
#  Query DDL a BQ: EXT_RENTABILIDAD_CAB_raw.sql
#  Query DDL a BQ: EXT_RENTABILIDAD_DET_raw.sql
#  Query DDL a BQ: EXT_RISKRESERVEJOB_raw.sql
#  Query DDL a BQ: INSURANCEOBJECTDCO_raw.sql
#  Query DDL a BQ: LUGAR_SINIESTRO_raw.sql
#  Query DDL a BQ: MIR_REP_VALORES_GARANTIZADOS_VIDA_202310_RAW.sql
#  Query DDL a BQ: OAACCIDENTEASISTEN_landing.sql
#  Query DDL a BQ: OAACCIDENTEASISTEN_raw.sql
#  Query DDL a BQ: OACLONACIONOFRAUDED_landing.sql
#  Query DDL a BQ: OACLONACIONOFRAUDED_raw.sql
#  Query DDL a BQ: OADESGHIPOTECARIOIND_landing.sql
#  Query DDL a BQ: OADESGHIPOTECARIOIND_raw.sql
#  Query DDL a BQ: OADESGHIPOTECARIO_landing.sql
#  Query DDL a BQ: OADESGHIPOTECARIO_raw.sql
#  Query DDL a BQ: OADESGPERSONALIND_landing.sql
#  Query DDL a BQ: OADESGPERSONALIND_raw.sql
#  Query DDL a BQ: OADESGPERSONAL_landing.sql
#  Query DDL a BQ: OADESGPERSONAL_raw.sql
#  Query DDL a BQ: OADESGTARJETASIND_landing.sql
#  Query DDL a BQ: OADESGTARJETASIND_raw.sql
#  Query DDL a BQ: OADESGTARJETAS_landing.sql
#  Query DDL a BQ: OADESGTARJETAS_raw.sql
#  Query DDL a BQ: OADESGVEHICULARIND_landing.sql
#  Query DDL a BQ: OADESGVEHICULARIND_raw.sql
#  Query DDL a BQ: OADESGVEHICULAR_landing.sql
#  Query DDL a BQ: OADESGVEHICULAR_raw.sql
#  Query DDL a BQ: OADOTALDOBLECAPITAL_raw.sql
#  Query DDL a BQ: OADOTALDOBLECREC_raw.sql
#  Query DDL a BQ: OADOTALDOBLEPROTEC_raw.sql
#  Query DDL a BQ: OADOTALSIMPLESURA_raw.sql
#  Query DDL a BQ: OADOTALSIMPLE_raw.sql
#  Query DDL a BQ: OADOTALTRIPLECREC_raw.sql
#  Query DDL a BQ: OADOTALTRIPLEPROTEC_raw.sql
#  Query DDL a BQ: OAEDUCACIONALSURA_raw.sql
#  Query DDL a BQ: OAEDUCGARANTIZADAPLUSNEW_raw.sql
#  Query DDL a BQ: OAEDUCGARANTIZADAPLUS_raw.sql
#  Query DDL a BQ: OAEDUCGARANTIZADA_raw.sql
#  Query DDL a BQ: OAEXTRACASHFUNO_landing.sql
#  Query DDL a BQ: OAEXTRACASHFUNO_raw.sql
#  Query DDL a BQ: OAEXTRACASH_landing.sql
#  Query DDL a BQ: OAEXTRACASH_raw.sql
#  Query DDL a BQ: OAFLEX65_landing.sql
#  Query DDL a BQ: OAFLEX65_raw.sql
#  Query DDL a BQ: OAFLEX80_landing.sql
#  Query DDL a BQ: OAFLEX80_raw.sql
#  Query DDL a BQ: OAGARANTIAEXTENDIDA_landing.sql
#  Query DDL a BQ: OAGARANTIAEXTENDIDA_raw.sql
#  Query DDL a BQ: OAINTELIGO_landing.sql
#  Query DDL a BQ: OAINTELIGO_raw.sql
#  Query DDL a BQ: OAINTERBANKACCIDENTES_landing.sql
#  Query DDL a BQ: OAINTERBANKACCIDENTES_raw.sql
#  Query DDL a BQ: OAINTERKIDS_landing.sql
#  Query DDL a BQ: OAINTERKIDS_raw.sql
#  Query DDL a BQ: OAMUERTEACCVIAJES_landing.sql
#  Query DDL a BQ: OAMUERTEACCVIAJES_raw.sql
#  Query DDL a BQ: OAPLANGARANTIZADO_raw.sql
#  Query DDL a BQ: OAPROTBLINDAJEINDPLUS_landing.sql
#  Query DDL a BQ: OAPROTBLINDAJEINDPLUS_raw.sql
#  Query DDL a BQ: OAPROTBLININDPLUSFUNO_landing.sql
#  Query DDL a BQ: OAPROTBLININDPLUSFUNO_raw.sql
#  Query DDL a BQ: OAPROTECCFINANCOH_landing.sql
#  Query DDL a BQ: OAPROTECCFINANCOH_raw.sql
#  Query DDL a BQ: OAPROTECCIONBLINDAJEPLUS_landing.sql
#  Query DDL a BQ: OAPROTECCIONBLINDAJEPLUS_raw.sql
#  Query DDL a BQ: OAPROTECCIONBLINDAJE_landing.sql
#  Query DDL a BQ: OAPROTECCIONBLINDAJE_raw.sql
#  Query DDL a BQ: OAPROTECCIONCREDITOSSCC_landing.sql
#  Query DDL a BQ: OAPROTECCIONCREDITOSSCC_raw.sql
#  Query DDL a BQ: OAPROTECCIONCREDITOS_landing.sql
#  Query DDL a BQ: OAPROTECCIONCREDITOS_raw.sql
#  Query DDL a BQ: OAPROTECCIONCREDITO_landing.sql
#  Query DDL a BQ: OAPROTECCIONCREDITO_raw.sql
#  Query DDL a BQ: OAPROTECCIONDEBITO_landing.sql
#  Query DDL a BQ: OAPROTECCIONDEBITO_raw.sql
#  Query DDL a BQ: OAPROTECCIONFAMILIAR_landing.sql
#  Query DDL a BQ: OAPROTECCIONFAMILIAR_raw.sql
#  Query DDL a BQ: OAPTINDIVIDUALIBK_raw.sql
#  Query DDL a BQ: OAPTINDIVIDUALOH_landing.sql
#  Query DDL a BQ: OAPTINDIVIDUALOH_raw.sql
#  Query DDL a BQ: OAREFINANCIADOCONV_landing.sql
#  Query DDL a BQ: OAREFINANCIADOCONV_raw.sql
#  Query DDL a BQ: OASCTR_landing.sql
#  Query DDL a BQ: OASCTR_raw.sql
#  Query DDL a BQ: OASEGUNDOASEGURADOSURA_raw.sql
#  Query DDL a BQ: OASEGUROACCIDENTES_raw.sql
#  Query DDL a BQ: OASEGUROTEMPDEVPRIMAS_raw.sql
#  Query DDL a BQ: OASEGVEHICULARMODULAR_landing.sql
#  Query DDL a BQ: OASEGVEHICULARMODULAR_raw.sql
#  Query DDL a BQ: OASIEMPRESEGURO_raw.sql
#  Query DDL a BQ: OASOAT_landing.sql
#  Query DDL a BQ: OASOAT_raw.sql
#  Query DDL a BQ: OATARJETADECREDITO_landing.sql
#  Query DDL a BQ: OATARJETADECREDITO_raw.sql
#  Query DDL a BQ: OATARJETADEDEBITO_landing.sql
#  Query DDL a BQ: OATARJETADEDEBITO_raw.sql
#  Query DDL a BQ: OATEMPGARANTIZADO100_raw.sql
#  Query DDL a BQ: OATEMPGARANTIZADO75_raw.sql
#  Query DDL a BQ: OATEMPORALSURA_raw.sql
#  Query DDL a BQ: OAVEAACCIDENTES_landing.sql
#  Query DDL a BQ: OAVEAACCIDENTES_raw.sql
#  Query DDL a BQ: OAVEAVIDA_landing.sql
#  Query DDL a BQ: OAVEAVIDA_raw.sql
#  Query DDL a BQ: OAVEHICULAR_raw.sql
#  Query DDL a BQ: OAVIDAENTERABENEFANT_raw.sql
#  Query DDL a BQ: OAVIDAENTERASURA_raw.sql
#  Query DDL a BQ: OAVIDAENTERA_raw.sql
#  Query DDL a BQ: OAVIDAESTUDIOSPLUS_landing.sql
#  Query DDL a BQ: OAVIDAESTUDIOSPLUS_raw.sql
#  Query DDL a BQ: OAVIDAESTUDIOS_landing.sql
#  Query DDL a BQ: OAVIDAESTUDIOS_raw.sql
#  Query DDL a BQ: OAVIDAFREE_landing.sql
#  Query DDL a BQ: OAVIDAFREE_raw.sql
#  Query DDL a BQ: OAVIDAGRUPOCOMP_landing.sql
#  Query DDL a BQ: OAVIDAGRUPOCOMP_raw.sql
#  Query DDL a BQ: OAVIDAINVERSION_landing.sql
#  Query DDL a BQ: OAVIDAINVERSION_raw.sql
#  Query DDL a BQ: OAVIDALEYTTL_landing.sql
#  Query DDL a BQ: OAVIDALEYTTL_raw.sql
#  Query DDL a BQ: OAVIDAPROTEGIDA_raw.sql
#  Query DDL a BQ: OAVIDATEMPORAL_raw.sql
#  Query DDL a BQ: OAVIDATOTALPROTEGIDA_raw.sql
#  Query DDL a BQ: OPENITEMREFERENCE_landing.sql
#  Query DDL a BQ: OPENITEMREFERENCE_raw.sql
#  Query DDL a BQ: OPENITEM_raw.sql
#  Query DDL a BQ: PAGADO_HASTA_landing.sql
#  Query DDL a BQ: PAGADO_HASTA_raw.sql
#  Query DDL a BQ: PAYMENTORDER_raw.sql
#  Query DDL a BQ: personajuridica.sql
#  Query DDL a BQ: PERSONAJURIDICA_raw.sql
#  Query DDL a BQ: personanatural.sql
#  Query DDL a BQ: PERSONANATURAL_raw.sql
#  Query DDL a BQ: PLAN_landing.sql
#  Query DDL a BQ: PLAN_raw.sql
#  Query DDL a BQ: POLACCIDENTEASISTEN_landing.sql
#  Query DDL a BQ: POLACCIDENTEASISTEN_raw.sql
#  Query DDL a BQ: POLCLONACIONOFRAUDED_landing.sql
#  Query DDL a BQ: POLCLONACIONOFRAUDED_raw.sql
#  Query DDL a BQ: POLDESGHIPOTECARIOIND_landing.sql
#  Query DDL a BQ: POLDESGHIPOTECARIOIND_raw.sql
#  Query DDL a BQ: POLDESGHIPOTECARIO_landing.sql
#  Query DDL a BQ: POLDESGHIPOTECARIO_raw.sql
#  Query DDL a BQ: POLDESGPERSONALIND_landing.sql
#  Query DDL a BQ: POLDESGPERSONALIND_raw.sql
#  Query DDL a BQ: POLDESGPERSONAL_landing.sql
#  Query DDL a BQ: POLDESGPERSONAL_raw.sql
#  Query DDL a BQ: POLDESGRAVAMENIND_landing.sql
#  Query DDL a BQ: POLDESGRAVAMENIND_raw.sql
#  Query DDL a BQ: POLDESGTARJETASIND_landing.sql
#  Query DDL a BQ: POLDESGTARJETASIND_raw.sql
#  Query DDL a BQ: POLDESGTARJETAS_landing.sql
#  Query DDL a BQ: POLDESGTARJETAS_raw.sql
#  Query DDL a BQ: POLDESGVEHICULARIND_landing.sql
#  Query DDL a BQ: POLDESGVEHICULARIND_raw.sql
#  Query DDL a BQ: POLDESGVEHICULAR_landing.sql
#  Query DDL a BQ: POLDESGVEHICULAR_raw.sql
#  Query DDL a BQ: POLDOTALDOBLECAPITAL_raw.sql
#  Query DDL a BQ: POLDOTALDOBLECREC_raw.sql
#  Query DDL a BQ: POLDOTALDOBLEPROTEC_raw.sql
#  Query DDL a BQ: POLDOTALSIMPLESURA_raw.sql
#  Query DDL a BQ: POLDOTALSIMPLE_raw.sql
#  Query DDL a BQ: POLDOTALTRIPLECREC_raw.sql
#  Query DDL a BQ: POLDOTALTRIPLEPROTEC_raw.sql
#  Query DDL a BQ: POLEDUCACIONALSURA_raw.sql
#  Query DDL a BQ: POLEDUCGARANTIZADAPLUSNEW_raw.sql
#  Query DDL a BQ: POLEDUCGARANTIZADAPLUS_raw.sql
#  Query DDL a BQ: POLEDUCGARANTIZADA_raw.sql
#  Query DDL a BQ: POLEXTRACASHFUNO_landing.sql
#  Query DDL a BQ: POLEXTRACASHFUNO_raw.sql
#  Query DDL a BQ: POLEXTRACASH_landing.sql
#  Query DDL a BQ: POLEXTRACASH_raw.sql
#  Query DDL a BQ: POLFLEX65_landing.sql
#  Query DDL a BQ: POLFLEX65_raw.sql
#  Query DDL a BQ: POLFLEX80_landing.sql
#  Query DDL a BQ: POLFLEX80_raw.sql
#  Query DDL a BQ: POLGARANTIAEXTENDIDA_landing.sql
#  Query DDL a BQ: POLGARANTIAEXTENDIDA_raw.sql
#  Query DDL a BQ: POLICYDCO_raw.sql
#  Query DDL a BQ: POLINTELIGO_landing.sql
#  Query DDL a BQ: POLINTELIGO_raw.sql
#  Query DDL a BQ: POLINTERBANKACCIDENTES_landing.sql
#  Query DDL a BQ: POLINTERBANKACCIDENTES_raw.sql
#  Query DDL a BQ: POLINTERKIDS_landing.sql
#  Query DDL a BQ: POLINTERKIDS_raw.sql
#  Query DDL a BQ: POLIZA_OPERACION_EVENT_raw.sql
#  Query DDL a BQ: POLMUERTEACCVIAJES_landing.sql
#  Query DDL a BQ: POLMUERTEACCVIAJES_raw.sql
#  Query DDL a BQ: POLPLANGARANTIZADO_raw.sql
#  Query DDL a BQ: POLPROTBLINDAJEINDPLUSFU_landing.sql
#  Query DDL a BQ: POLPROTBLINDAJEINDPLUSFU_raw.sql
#  Query DDL a BQ: POLPROTBLINDAJEINDPLUS_landing.sql
#  Query DDL a BQ: POLPROTBLINDAJEINDPLUS_raw.sql
#  Query DDL a BQ: POLPROTECCFINANCOH_landing.sql
#  Query DDL a BQ: POLPROTECCFINANCOH_raw.sql
#  Query DDL a BQ: POLPROTECCIONBLINDAJEPLUS_landing.sql
#  Query DDL a BQ: POLPROTECCIONBLINDAJEPLUS_raw.sql
#  Query DDL a BQ: POLPROTECCIONBLINDAJE_landing.sql
#  Query DDL a BQ: POLPROTECCIONBLINDAJE_raw.sql
#  Query DDL a BQ: POLPROTECCIONCREDITOSSCC_landing.sql
#  Query DDL a BQ: POLPROTECCIONCREDITOSSCC_raw.sql
#  Query DDL a BQ: POLPROTECCIONCREDITOS_landing.sql
#  Query DDL a BQ: POLPROTECCIONCREDITOS_raw.sql
#  Query DDL a BQ: POLPROTECCIONDEBITO_landing.sql
#  Query DDL a BQ: POLPROTECCIONDEBITO_raw.sql
#  Query DDL a BQ: POLPROTECCIONFAMILIAR_landing.sql
#  Query DDL a BQ: POLPROTECCIONFAMILIAR_raw.sql
#  Query DDL a BQ: POLPTINDIVIDUALIBK_landing.sql
#  Query DDL a BQ: POLPTINDIVIDUALIBK_raw.sql
#  Query DDL a BQ: POLPTINDIVIDUALOH_landing.sql
#  Query DDL a BQ: POLPTINDIVIDUALOH_raw.sql
#  Query DDL a BQ: POLREFINANCIADOCONV_landing.sql
#  Query DDL a BQ: POLREFINANCIADOCONV_raw.sql
#  Query DDL a BQ: POLREFINANCIADOIND_landing.sql
#  Query DDL a BQ: POLREFINANCIADOIND_raw.sql
#  Query DDL a BQ: POLSCTR_landing.sql
#  Query DDL a BQ: POLSCTR_raw.sql
#  Query DDL a BQ: POLSEGUNDOASEGURADOSURA_raw.sql
#  Query DDL a BQ: POLSEGUROACCIDENTES_raw.sql
#  Query DDL a BQ: POLSEGVEHICULARMODULAR_landing.sql
#  Query DDL a BQ: POLSEGVEHICULARMODULAR_raw.sql
#  Query DDL a BQ: POLSIEMPRESEGURO_raw.sql
#  Query DDL a BQ: POLSOAT_raw.sql
#  Query DDL a BQ: POLTARJETADECREDITO_landing.sql
#  Query DDL a BQ: POLTARJETADECREDITO_raw.sql
#  Query DDL a BQ: POLTARJETADEDEBITO_raw.sql
#  Query DDL a BQ: POLTEMDEVPRIMA_raw.sql
#  Query DDL a BQ: POLTEMPGARANTIZADO100_raw.sql
#  Query DDL a BQ: POLTEMPGARANTIZADO75_raw.sql
#  Query DDL a BQ: POLTEMPORALSURA_raw.sql
#  Query DDL a BQ: POLVEAACCIDENTES_landing.sql
#  Query DDL a BQ: POLVEAACCIDENTES_raw.sql
#  Query DDL a BQ: POLVEAVIDA_landing.sql
#  Query DDL a BQ: POLVEAVIDA_raw.sql
#  Query DDL a BQ: POLVEHICULAR_raw.sql
#  Query DDL a BQ: PolVidaCashStock_landing.sql
#  Query DDL a BQ: PolVidaCashStock_raw.sql
#  Query DDL a BQ: PolVidaCash_raw.sql
#  Query DDL a BQ: POLVIDAENTERABENEFANT_raw.sql
#  Query DDL a BQ: POLVIDAENTERASURA_raw.sql
#  Query DDL a BQ: POLVIDAENTERA_raw.sql
#  Query DDL a BQ: POLVIDAESTUDIOSPD_landing.sql
#  Query DDL a BQ: POLVIDAESTUDIOSPD_raw.sql
#  Query DDL a BQ: POLVIDAESTUDIOS_landing.sql
#  Query DDL a BQ: POLVIDAESTUDIOS_raw.sql
#  Query DDL a BQ: POLVIDAFREE_landing.sql
#  Query DDL a BQ: POLVIDAFREE_raw.sql
#  Query DDL a BQ: POLVIDAGRUPOCOMP_landing.sql
#  Query DDL a BQ: POLVIDAGRUPOCOMP_raw.sql
#  Query DDL a BQ: POLVIDAINVERSION_landing.sql
#  Query DDL a BQ: POLVIDAINVERSION_raw.sql
#  Query DDL a BQ: POLVIDALEYTTL_landing.sql
#  Query DDL a BQ: POLVIDALEYTTL_raw.sql
#  Query DDL a BQ: POLVIDAPROTEGIDA_raw.sql
#  Query DDL a BQ: POLVIDATEMPORAL_raw.sql
#  Query DDL a BQ: POLVIDATOTALPROTEGIDA_raw.sql
#  Query DDL a BQ: PREINSUREDOBJECT_raw.sql
#  Query DDL a BQ: PREPOLICY_raw.sql
#  Query DDL a BQ: PREPRODUCT_landing.sql
#  Query DDL a BQ: PREPRODUCT_raw.sql
#  Query DDL a BQ: PRETHIRDPARTY_raw.sql
#  Query DDL a BQ: PRIMA_OPERACION_COBERTURA_raw.sql
#  Query DDL a BQ: PRODUCT_landing.sql
#  Query DDL a BQ: PRODUCT_raw.sql
#  Query DDL a BQ: PROPERTY_landing.sql
#  Query DDL a BQ: PROPERTY_raw.sql
#  Query DDL a BQ: REFUND_PORCENTAGE_landing.sql
#  Query DDL a BQ: RISKUNITDCO_raw.sql
#  Query DDL a BQ: Siniestro_ti_landing.sql
#  Query DDL a BQ: STATE_landing.sql
#  Query DDL a BQ: STATE_raw.sql
#  Query DDL a BQ: STCA_DOCTYPE_landing.sql
#  Query DDL a BQ: STCA_DOCTYPE_raw.sql
#  Query DDL a BQ: STCL_COVERAGEINVOICE_landing.sql
#  Query DDL a BQ: STCL_COVERAGEINVOICE_raw.sql
#  Query DDL a BQ: stcl_paymentliquidation.sql
#  Query DDL a BQ: STLI_FUNDMOVEMENTPOLICY_raw.sql
#  Query DDL a BQ: STPO_INSOBJPARTICIPATIONDCO_raw.sql
#  Query DDL a BQ: STPO_INSOBJPARTICIPATION_raw.sql
#  Query DDL a BQ: STPO_POLICYPARTICIPATIONDCO_landing.sql
#  Query DDL a BQ: STPO_POLICYPARTICIPATIONDCO_raw.sql
#  Query DDL a BQ: STPO_POLICYPARTICIPATION_raw.sql
#  Query DDL a BQ: STPO_WILDCARDQUOTA_raw.sql
#  Query DDL a BQ: STTE_THIRDPARTYADDRESSBOOK_raw.sql
#  Query DDL a BQ: STTE_THIRDPARTY_raw.sql
#  Query DDL a BQ: STTS_ROLE_landing.sql
#  Query DDL a BQ: STTS_ROLE_raw.sql
#  Query DDL a BQ: TBL_UBIGEO_landing.sql
#  Query DDL a BQ: TBL_UBIGEO_raw.sql
#  Query DDL a BQ: TCM007_202312_RAW.sql
#  Query DDL a BQ: TCM007_EXTRACASH_FUNO062023_RAW.sql
#  Query DDL a BQ: TCM007_OTROS102023_raw.sql
#  Query DDL a BQ: TCM007_SOAT102023_raw.sql
#  Query DDL a BQ: TDTASACAMBSBS_raw.sql
#  Query DDL a BQ: TD_ESTADO_ANULAR_raw.sql
#  Query DDL a BQ: TD_ESTADO_CADUCAR_raw.sql
#  Query DDL a BQ: TD_ESTADO_CANCELAR_raw.sql
#  Query DDL a BQ: TD_ESTADO_ENDOSO_landing.sql
#  Query DDL a BQ: TD_ESTADO_ENDOSO_raw.sql
#  Query DDL a BQ: TD_ESTADO_RECHAZAR_raw.sql
#  Query DDL a BQ: TD_ESTADO_REHABILITAR_raw.sql
#  Query DDL a BQ: TD_ESTADO_RENOVAR_raw.sql
#  Query DDL a BQ: TD_ESTADO_RESCATAR_raw.sql
#  Query DDL a BQ: TD_ESTADO_TERMINAR_raw.sql
#  Query DDL a BQ: TD_OPENITEM.sql
#  Query DDL a BQ: TD_OPENITEM_COMPROBANTE.sql
#  Query DDL a BQ: TD_OPENITEM_MAESTRA_raw.sql
#  Query DDL a BQ: TD_OPERACION_BENEFICIARIO_POL_raw.sql
#  Query DDL a BQ: TD_OPERACION_BENEFICIARIO_raw.sql
#  Query DDL a BQ: TD_OPERACION_MASIVOS_raw.sql
#  Query DDL a BQ: TD_OPERACION_SOAT_raw.sql
#  Query DDL a BQ: TD_OPERACION_UNIDAD_RIESGO_raw.sql
#  Query DDL a BQ: TD_OPERACION_VEHICULAR_raw.sql
#  Query DDL a BQ: TD_OPERACION_VIDA_AGENTE_raw.sql
#  Query DDL a BQ: TD_POLIZA_ASEGURADO_BETTERFLY_raw.sql
#  Query DDL a BQ: TD_POLIZA_ASEGURADO_DESGTARJETASIND_raw.sql
#  Query DDL a BQ: TD_POLIZA_ASEGURADO_raw.sql
#  Query DDL a BQ: TD_POLIZA_COMODIN_raw.sql
#  Query DDL a BQ: TD_POLIZA_CONTRATANTE_GE_raw.sql
#  Query DDL a BQ: TD_POLIZA_CONTRATANTE_landing.sql
#  Query DDL a BQ: TD_POLIZA_CONTRATANTE_raw.sql
#  Query DDL a BQ: TD_POLIZA_ENDOSO_raw.sql
#  Query DDL a BQ: TD_POLIZA_OPERACION_COBERTURA_raw.sql
#  Query DDL a BQ: TD_POLIZA_OPERACION_UNIDAD_RIESGO_raw.sql
#  Query DDL a BQ: TD_POLIZA_SINIESTRO_landing.sql
#  Query DDL a BQ: TD_POLIZA_SINIESTRO_PAGO_raw.sql
#  Query DDL a BQ: TD_POLIZA_SINIESTRO_raw.sql
#  Query DDL a BQ: TD_POLIZA_SINIESTRO_RESERVA_landing.sql
#  Query DDL a BQ: TD_POLIZA_SINIESTRO_RESERVA_raw.sql
#  Query DDL a BQ: TD_POLIZA_TVG_raw.sql
#  Query DDL a BQ: TD_PRODUCTO_CENTRO_COSTO_raw.sql
#  Query DDL a BQ: TD_PRODUCTO_raw.sql
#  Query DDL a BQ: THIRDPARTYMOVEMENTPOLICY_landing.sql
#  Query DDL a BQ: THIRDPARTYMOVEMENTPOLICY_raw.sql
#  Query DDL a BQ: URPVIDAFREE_raw.sql
#  Query DDL a BQ: URSEGVEHICULARMODULAR_raw.sql
#  Query DDL a BQ: URVEHICULAR_landing.sql
#  Query DDL a BQ: URVEHICULAR_raw.sql
#  Query DDL a BQ: URVIDAFREE_landing.sql
#  Query DDL a BQ: URVIDATOTALPROTEGIDA_landing.sql
#  Query DDL a BQ: URVIDATOTALPROTEGIDA_raw.sql
#  Query DDL a BQ: VIEW_PRESTAMO_raw.sql
#  Query DDL a BQ: VIEW_PROPIEDAD_VALORES_raw.sql
#  Query DDL a BQ: VIEW_PROPLISTA_DEPEN_raw.sql

# %% [markdown]
# ### Genera los archivos sql con los insert

# %%
external_to_table(path_insert,dataset_id,dataset_output,dataset_input)

# %%
#execute_job_bq(path_insert,'Insert')
# Out:
#  Query insert a BQ: CLAIM_raw.sql
#  Query insert a BQ: COBERTURA_raw.sql

# %% [markdown]
# ### Ejecutar

# %%
# Ejecuta la exportacion a cloud storage del todo un dataset entero 
main_export_storage()
# Crea los DDL para las tablas externas y los ejecuta en bq
main_create_external_table()
# genera los insert de las tablas externas a tabla en bq
external_to_table(path_insert,dataset_id,dataset_output,dataset_input)
# Aqui falta sumar el truncate table pero es riesgoso (evaluar)

# Ejecuta todos los insert 
execute_job_bq(path_insert)
