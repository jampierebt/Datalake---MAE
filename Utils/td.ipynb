# %%
from google.cloud import bigquery
import re
import os
import pandas as pd

project_id = 'interseguro-data'
client = bigquery.Client(project_id)

# %%
path = 'sql/query_table_td.sql'

# %%
def sqlbigquery(filename):
    with open(filename,"r") as file:
        statement = file.readlines()
        statement = " ".join(statement)
    print(f" {filename}")
    return statement

def read_table_bq(sql,project_id):
    df = pd.read_gbq(sql, project_id=project_id, dialect='standard')
    # return df

# %%
data = sqlbigquery(path)
# Out:
#  sql/query_table_td.sql

# %%
data
dt = read_table_bq(data,'interseguro-data')
# Out:
# C:\Users\jberriot\AppData\Local\Temp\ipykernel_24808\1548228319.py:9: FutureWarning: read_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.read_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.read_gbq
#   df = pd.read_gbq(sql, project_id=project_id, dialect='standard')
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas_gbq\query.py:85, in try_query(connector, query_fn)
#      84     logger.debug("Requesting query... ")
# ---> 85     return query_fn()
#      86 except concurrent.futures.TimeoutError as ex:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\google\cloud\bigquery\client.py:3601, in Client.query_and_wait(self, query, job_config, location, project, api_timeout, wait_timeout, retry, job_retry, page_size, max_results)
# ...

# %%
# Out:
# C:\Users\jberriot\AppData\Local\Temp\ipykernel_24808\1548228319.py:9: FutureWarning: read_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.read_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.read_gbq
#   df = pd.read_gbq(sql, project_id=project_id, dialect='standard')
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas_gbq\query.py:85, in try_query(connector, query_fn)
#      84     logger.debug("Requesting query... ")
# ---> 85     return query_fn()
#      86 except concurrent.futures.TimeoutError as ex:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\google\cloud\bigquery\client.py:3601, in Client.query_and_wait(self, query, job_config, location, project, api_timeout, wait_timeout, retry, job_retry, page_size, max_results)
# ...

# %%
df = pd.read_excel('COLUMNAS_ORACLE.xlsx')
#df.to_parquet('COLUMNAS_ORACLE.parquet',index=False)

# %%
da = pd.read_excel('POLIZA_VIDA_ENDOSO.xlsx')

# %%
result = pd.merge(da, df, on='TABLE_NAME', how='inner')

# %%
filtered_df = df[df['TABLE_NAME'].isin(['APLAZARPROPUESTA', 'CAMBIARPROPUESTA','OBSERVARPROPUESTA'])]

# %%
lista = filtered_df['TABLE_NAME'].unique()

# %%
for name in lista:
    print(name)
    for i in enumerate(filtered_df):
        var = filtered_df['TABLE_NAME']
        print(i)
# Out:
# APLAZARPROPUESTA
# (0, 'OWNER')
# (1, 'TABLE_NAME')
# (2, 'COLUMN_NAME')
# (3, 'DATA_TYPE')
# (4, 'DATA_LENGTH')
# (5, 'NULLABLE')
# (6, 'COLUMN_ID')
# CAMBIARPROPUESTA
# (0, 'OWNER')
# (1, 'TABLE_NAME')
# (2, 'COLUMN_NAME')
# (3, 'DATA_TYPE')
# (4, 'DATA_LENGTH')
# (5, 'NULLABLE')
# (6, 'COLUMN_ID')
# OBSERVARPROPUESTA
# (0, 'OWNER')
# (1, 'TABLE_NAME')
# (2, 'COLUMN_NAME')
# (3, 'DATA_TYPE')
# (4, 'DATA_LENGTH')
# (5, 'NULLABLE')
# (6, 'COLUMN_ID')

# %%
result.to_excel('testo.xlsx',index=False)
#APLAZARPROPUESTA
#CAMBIARPROPUESTA
#OBSERVARPROPUESTA
